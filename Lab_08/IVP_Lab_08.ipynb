# %% [markdown]
# 1. Write a program for performing following morphological operations <br>
# a) Erosion <br>
# b) Dilation <br>
# c) Opening <br>
# d) Closing <br>

# %%
import matplotlib.pyplot as plt
from skimage.io import imread, imsave
from skimage.morphology import erosion, dilation, opening, closing, white_tophat
from skimage.morphology import black_tophat, skeletonize, convex_hull_image
from skimage.morphology import disk, square, diamond
from skimage.color import rgb2gray
from skimage.util import img_as_ubyte

# %%
img = imread('images/deer.png', as_gray = True)
print(img.shape)
img = rgb2gray(img)
plt.imshow(img, cmap = 'gray')
plt.show()
# Out:
# (600, 672)

# %%
# erosion
erosion_img = erosion(img)
plt.imshow(erosion_img, cmap = 'gray')

# %%
# dilation
dilation_img = dilation(img)
plt.imshow(dilation_img, cmap = 'gray')

# %%
# opening
opening_img = opening(img)
plt.imshow(opening_img, cmap = 'gray')

# %%
# closing 
closing_img = closing(img)
plt.imshow(closing_img, cmap = 'gray')

# %%
# all in one plot

plt.figure(figsize = (10, 10))
plt.subplot(151)
plt.title("input")
plt.axis('off')
plt.imshow(img, cmap = 'gray')

plt.subplot(152)
plt.title("erosion")
plt.axis('off')
plt.imshow(erosion_img, cmap = 'gray')

plt.subplot(153)
plt.title("dilation")
plt.axis('off')
plt.imshow(dilation_img, cmap = 'gray')

plt.subplot(154)
plt.title("opening")
plt.axis('off')
plt.imshow(opening_img, cmap = 'gray')

plt.subplot(155)
plt.title("closing")
plt.axis('off')
plt.imshow(closing_img, cmap = 'gray')

# %% [markdown]
# 2. Perform opening and closing operations for removing salt and pepper noise
# For this, you should use an image with salt and pepper noise as input. One such image is provided below.

# %%
# a) Apply ‘opening’ over original noisy image and show the removal of salt noisy components

# %%
from skimage.io import imread, imsave, imshow, show, imread_collection, imshow_collection
from skimage import color, viewer, exposure, img_as_float, data
from skimage.color import rgb2gray
import matplotlib.pylab as plt
from scipy import ndimage
# Out:
# C:\Users\vinee\anaconda3\lib\site-packages\skimage\viewer\utils\__init__.py:1: UserWarning: Recommended matplotlib backend is `Agg` for full skimage.viewer functionality.
#   from .core import *

# %%
img = rgb2gray(imread('images/mandrill_noisy.png'))
plt.imshow(img,cmap='gray')

# %%
# opening
opening_img = opening(img)
plt.imshow(opening_img, cmap = 'gray')

# %%
# b) Apply ‘closing’ over original noisy image and show the removal of pepper noisy components

# %%
# closing
closing_img = closing(img)
plt.imshow(closing_img, cmap = 'gray')

# %%
# c) Apply ‘opening’ and then ‘closing’ over original noisy image and show the removal of both salt and pepper noisy components

# %%
final_img = closing(opening_img)
plt.imshow(final_img, cmap = 'gray')

# %% [markdown]
# 3. Perform opening and then closing operation for noise removal of fingerprint image given below.

# %%
from skimage.io import imread, imsave, imshow, show, imread_collection, imshow_collection
from skimage import color, viewer, exposure, img_as_float, data
from skimage.color import rgb2gray
from skimage.morphology import binary_opening, binary_closing, disk
from skimage.morphology import disk, square
import matplotlib.pylab as plt
from scipy import ndimage

# %%
fp = rgb2gray(imread('images/fingerprint.png'))
plt.imshow(fp, cmap = 'gray')

# %%
# opening
fp_opening = opening(fp)
plt.imshow(fp_opening, cmap = 'gray')

# %%
# closing 
fp_closing = closing(fp)
plt.imshow(fp_closing, cmap = 'gray')

# %%
# print both
fp_final = closing(fp_opening)
plt.imshow(fp_final, cmap = 'gray')

# %%
plt.figure(figsize = (10, 10))

plt.subplot(141)
plt.axis('off')
plt.title('input')
plt.imshow(fp, cmap = 'gray')

plt.subplot(142)
plt.axis('off')
plt.title('opening')
plt.imshow(fp_opening, cmap = 'gray')

plt.subplot(143)
plt.axis('off')
plt.title('closing')
plt.imshow(fp_closing, cmap = 'gray')

plt.subplot(144)
plt.axis('off')
plt.title('both')
plt.imshow(fp_final, cmap = 'gray')
